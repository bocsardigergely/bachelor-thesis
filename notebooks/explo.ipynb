# %%
import pandas as pd
import ast

# %%
data = pd.read_csv("../data/nlp_ready.csv", converters={1:ast.literal_eval, 0:ast.literal_eval})
# this way I get proper lists in the df instead of strings formatted like lists
data["processed_words"][1][2]
# Out:
# 'barter'

# %% [markdown]
# # Word clouds

# %%
bag = []
title_bag = []
word_bag = []
for ind in data.index:
    title_bag += data["processed_title"][ind]
    word_bag += data["processed_words"][ind]
    bag += data["processed_words"][ind] + data["processed_title"][ind]
len(bag)
# Out:
# 851642

# %%
from collections import Counter
all_words_count = Counter(bag)
title_count = Counter(title_bag)
words_count = Counter(word_bag)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
wordcloud_all = WordCloud(width = 1000, height = 1000).generate_from_frequencies(all_words_count)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud_all)
plt.axis("off")
plt.show()

# %%
wordcloud_title = WordCloud(width = 1000, height = 1000).generate_from_frequencies(title_count)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud_title)
plt.axis("off")
plt.show()

# %%
wordcloud_words = WordCloud(width = 1000, height = 1000).generate_from_frequencies(words_count)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud_words)
plt.axis("off")
plt.show()
