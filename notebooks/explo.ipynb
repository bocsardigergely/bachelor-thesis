# %%
import pandas as pd
import ast

# %%
data = pd.read_csv("../data/nlp_ready.csv", converters={0:ast.literal_eval})
# this way I get proper lists in the df instead of strings formatted like lists
data["processed_words"][1][2]
# Out:
# 'barter'

# %% [markdown]
# # Word clouds

# %%
bag = []
for ind in data.index:
    bag += data["processed_words"][ind]
len(bag)
# Out:
# 851642

# %%
from collections import Counter
all_words_count = Counter(bag)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
wordcloud_all = WordCloud(width = 1000, height = 1000, background_color='white').generate_from_frequencies(all_words_count)

plt.figure(figsize=(15,8))
wordcloud_all.to_file('../images/wordcloud_light.png')
plt.imshow(wordcloud_all)
plt.axis("off")
plt.show()
