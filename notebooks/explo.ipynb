# %%
import pandas as pd

# %%
data = pd.read_csv("../data/nlp_ready.csv")
data.head(2)
# Out:
#                                      processed_words   ups  ups_normed  \
# 0  sometimesth face go work get shoot strong anti...   1.0    0.000001
# 1  time come barter pandem day roll toilet paper ...  27.0    0.000036
#
#    TextLength  Sentiment  word_count  dank_level
# 0       118.0       0.58         8.0         0.0
# 1        93.0       0.29         8.0         0.0

# %%
data['dank_level'].value_counts(normalize=True)
#this is the 0-1 ratio
# Out:
# 0.0    0.950649
# 1.0    0.049351
# Name: dank_level, dtype: float64

# %% [markdown]
# # Word clouds

# %%
bag = []
for ind in data.index:
    word_list = []
    word_list = data["processed_words"][ind].split()
    bag += word_list
len(bag)
# Out:
# 851642

# %%
from collections import Counter
all_words_count = Counter(bag)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
wordcloud_all = WordCloud(width = 1000, height = 1000, background_color='white').generate_from_frequencies(all_words_count)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud_all)
plt.axis("off")
plt.show()
